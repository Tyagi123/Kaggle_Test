# %%
#https://www.kaggle.com/c/dog-vs-cat-classification/data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
#initializing the cnn
classifier=Sequential()

# %%
# Generating images for the Test set
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Creating training set
training_set = train_datagen.flow_from_directory('/Users/gauravtyagi/Downloads/Data/dog-vs-cat-classification/train/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Creating the Test set
test_set = test_datagen.flow_from_directory('/Users/gauravtyagi/Downloads/data/dog-vs-cat-classification/test/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 25000 images belonging to 2 classes.
# Found 0 images belonging to 0 classes.

# %%
training_set.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
#step1-convolution
classifier.add(Convolution2D(32,3,3,input_shape=(64,64,3),activation='relu'))
#step2-maxpooling
classifier.add(MaxPooling2D(pool_size=(2,2)))
#step3-flattening
classifier.add(Flatten())
#step4-fullconnection
classifier.add(Dense(output_dim=128,activation='relu'))
classifier.add(Dense(output_dim=1,activation='sigmoid'))
# Out:
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 3...)`
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-efc2bac2865c> in <module>()
#       1 #step1-convolution
# ----> 2 classifier.add(Convolution2D(32,3,3,input_shape=(64,64,3),activation='relu'))
#       3 #step2-maxpooling
#       4 classifier.add(MaxPooling2D(pool_size=(2,2)))
#       5 #step3-flattening
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/sequential.py in add(self, layer)
#     183                 self.inputs = network.get_source_inputs(self.outputs[0])
#     184         elif self.outputs:
# --> 185             output_tensor = layer(self.outputs[0])
#     186             if isinstance(output_tensor, list):
#     187                 raise TypeError('All layers in a Sequential model '
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     412                 # Raise exceptions in case the input is not compatible
#     413                 # with the input_spec specified in the layer constructor.
# --> 414                 self.assert_input_compatibility(inputs)
#     415
#     416                 # Collect input shapes to build layer.
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/base_layer.py in assert_input_compatibility(self, inputs)
#     309                                      self.name + ': expected ndim=' +
#     310                                      str(spec.ndim) + ', found ndim=' +
# --> 311                                      str(K.ndim(x)))
#     312             if spec.max_ndim is not None:
#     313                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer conv2d_3: expected ndim=4, found ndim=2

# %%
classifier.fit_generator(training_set,samples_per_epoch=8000,nb_epoch=25,validation_data=test_set,nb_val_samples=2000)
# Out:
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """Entry point for launching an IPython kernel.
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., epochs=25, validation_data=<keras_pre..., validation_steps=2000, steps_per_epoch=250)`
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-81861a3ae2c6> in <module>()
# ----> 1 classifier.fit_generator(training_set,samples_per_epoch=8000,nb_epoch=25,validation_data=test_set,nb_val_samples=2000)
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#      37
#      38     do_validation = bool(validation_data)
# ---> 39     model._make_train_function()
#      40     if do_validation:
#      41         model._make_test_function()
#
# /Users/gauravtyagi/opt/anaconda3/envs/Dev/lib/python3.5/site-packages/keras/engine/training.py in _make_train_function(self)
#     483     def _make_train_function(self):
#     484         if not hasattr(self, 'train_function'):
# --> 485             raise RuntimeError('You must compile your model before using it.')
#     486         self._check_trainable_weights_consistency()
#     487         if self.train_function is None:
#
# RuntimeError: You must compile your model before using it.
