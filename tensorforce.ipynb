# %%
import tensorforce

# %%
environment = Environment.create(
    environment='gym', level='CartPole', max_episode_timesteps=500
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5272aa88f4af> in <module>
# ----> 1 environment = Environment.create(
#       2     environment='gym', level='CartPole', max_episode_timesteps=500
#       3 )
#
# NameError: name 'Environment' is not defined

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
environment = Environment.create(environment='gym', level='CartPole-v1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-54ba4fd0075f> in <module>
# ----> 1 environment = Environment.create(environment='gym', level='CartPole-v1')
#
# NameError: name 'Environment' is not defined

# %%
{
    "environment": "gym",
    "level": "CartPole"
}
# Out:
# {'environment': 'gym', 'level': 'CartPole'}

# %%
environment = Environment.create(
    environment='environment.json', max_episode_timesteps=500
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-442f54e8a5de> in <module>
# ----> 1 environment = Environment.create(
#       2     environment='environment.json', max_episode_timesteps=500
#       3 )
#
# NameError: name 'Environment' is not defined

# %%
import tensorflow as tf

# %%
from rl.agents.dqn import DQNAgent
from rl.policy import EpsGreedyQPolicy
from rl.memory import SequentialMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/xz/tjb1tdxs54l7j3mvjy0yn3fc0000gn/T/ipykernel_27940/664268600.py in <module>
# ----> 1 from rl.agents.dqn import DQNAgent
#       2 from rl.policy import EpsGreedyQPolicy
#       3 from rl.memory import SequentialMemory
#
# ModuleNotFoundError: No module named 'rl'

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split
